# %%
# load previous data 

import pickle

with open('sample_eval_rows.bin', 'rb') as f_in:
    rows = pickle.load(f_in)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       3 import pickle
#       5 with open('sample_eval_rows.bin', 'rb') as f_in:
# ----> 6     rows = pickle.load(f_in)
#
# ModuleNotFoundError: No module named 'search_agent'
