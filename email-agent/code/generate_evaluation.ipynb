# %% [markdown]
# # Email Agent Evaluation: Questions from Real Data
#
# This notebook implements the Week 3 evaluation approach for the email agent.
#
# ## Process Overview
# 1. **Fetch Real Data**: Connect to Elasticsearch and retrieve actual email data
# 2. **Analyze Data**: Understand the structure and content of emails
# 3. **Generate Questions**: Use LLM to create questions based on the real data
# 4. **Ask Agent**: Interact with agent using generated questions
# 5. **Evaluate Responses**: Document results and assessment
# 6. **Save Results**: Export questions and evaluation results to CSV

# %% [markdown]
# ## Section 1: Setup and Initialize

# %%
import os
import sys
from pathlib import Path
import json
from datetime import datetime

# Add email_agent to path
sys.path.insert(0, str(Path.cwd()))

from dotenv import load_dotenv
import pandas as pd
from openai import OpenAI

# Load environment
load_dotenv()

print("✅ Setup complete")
